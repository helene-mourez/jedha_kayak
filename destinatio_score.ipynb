# %%
# Import des librairies pour l'EDA de Kayak
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go

# %%
final_df = pd.read_csv("/Users/nicolasbour/Desktop/Projets_IA /Projets_certif/02_kayak/data/final_data_test.csv")
pd.set_option('display.max_columns', None)
final_df
# Out:
#                             city   place_id        lat       lon      base  \
# 0              mont saint michel  285390554  48.635954 -1.511460  stations
# 1                     saint malo  284423924  48.649518 -2.026041  stations
# 2                         bayeux  280655053  49.276462 -0.702474  stations
# 3                       le havre  100021883  49.493898  0.107973  stations
# 4                          rouen   99438300  49.440459  1.093966  stations
# 5                          paris   97347287  48.853495  2.348391  stations
# 6                         amiens   99360340  49.894171  2.295695  stations
# 7                          lille  101870667  50.636565  3.063528  stations
# 8                     strasbourg  120878363  48.584614  7.750713  stations
# 9   chateau du haut koenigsbourg  121188411  48.249382  7.343941  stations
# 10                        colmar  120649250  48.077752  7.357964  stations
# ...

# %%
df = final_df.copy()

# %%
df = df.drop(columns=['sys.type', "city", "lat", "lon", "dt", "sys.sunrise", "place_id", "base", "timezone", "id", "name", "cod", "coord.lon", "coord.lat" ,"sys.sunset", "weather.0.id", "weather.0.icon", "hotels", 'sys.id', "sys.country"])

# %%
df
# Out:
#     visibility  main.temp  main.feels_like  main.temp_min  main.temp_max  \
# 0        10000      24.25            24.01          24.25          24.25
# 1        10000      23.29            23.24          23.21          23.29
# 2         7429      25.14            25.33          25.14          25.14
# 3        10000      23.55            23.74          23.55          24.90
# 4        10000      25.58            25.71          24.60          26.44
# 5        10000      26.24            26.24          25.10          27.92
# 6        10000      27.66            28.32          27.66          27.66
# 7        10000      28.40            29.45          26.66          29.38
# 8        10000      31.53            31.46          30.72          33.62
# 9        10000      26.90            27.21          26.90          27.24
# 10       10000      30.09            31.18          29.94          31.70
# 11       10000      30.07            31.15          29.21          30.24
# ...

# %%
df.to_csv("/Users/nicolasbour/Desktop/Projets_IA /Projets_certif/02_kayak/data/final_data_test_cleaned.csv", index=False)

# %%
df_scored = pd.read_csv("/Users/nicolasbour/Desktop/Projets_IA /Projets_certif/02_kayak/final_data_test_scored.csv")

# %%
df_scored
# Out:
#     visibility  main.temp  main.feels_like  main.temp_min  main.temp_max  \
# 0        10000      24.25            24.01          24.25          24.25
# 1        10000      23.29            23.24          23.21          23.29
# 2         7429      25.14            25.33          25.14          25.14
# 3        10000      23.55            23.74          23.55          24.90
# 4        10000      25.58            25.71          24.60          26.44
# 5        10000      26.24            26.24          25.10          27.92
# 6        10000      27.66            28.32          27.66          27.66
# 7        10000      28.40            29.45          26.66          29.38
# 8        10000      31.53            31.46          30.72          33.62
# 9        10000      26.90            27.21          26.90          27.24
# 10       10000      30.09            31.18          29.94          31.70
# 11       10000      30.07            31.15          29.21          30.24
# ...

# %%
df_scored.describe()
# Out:
#          visibility  main.temp  main.feels_like  main.temp_min  main.temp_max  \
# count     35.000000  35.000000        35.000000      35.000000      35.000000
# mean    9926.542857  28.574571        29.989429      28.000000      29.272571
# std      434.578318   3.673235         4.874421       3.409031       3.902644
# min     7429.000000  20.210000        20.400000      20.070000      20.740000
# 25%    10000.000000  26.005000        26.400000      25.320000      26.545000
# 50%    10000.000000  28.910000        30.580000      28.470000      29.380000
# 75%    10000.000000  31.545000        34.235000      30.640000      32.810000
# max    10000.000000  35.450000        37.960000      33.760000      36.180000
#
#        main.pressure  main.humidity  main.sea_level  main.grnd_level  \
# count      35.000000      35.000000       35.000000         35.00000
# mean     1010.371429      55.714286     1010.371429        985.60000
# ...

# %%
# Affichade la distribution des scores
plt.figure(figsize=(10, 6))
sns.histplot(df_scored['weather_scores'], bins=20, kde=True, color='blue')
plt.title('Distribution des scores de météo', fontsize=16)
# Out:
# Text(0.5, 1.0, 'Distribution des scores de météo')
