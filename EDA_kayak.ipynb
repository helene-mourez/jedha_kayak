# %%
# Import des librairies pour l'EDA de Kayak
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
final_df = pd.read_csv("data/final_data_exercise_list.csv")

# %%
final_df.head()

# %%
# Définition des critères de
